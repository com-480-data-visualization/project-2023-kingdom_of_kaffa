# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/kofio_dataset.csv',sep='\t')

# %% [markdown]
# ## Insight on our dataset

# %%
df.head(20)
# Out:
#                                             Item Name          Roastery  \
# 0   Ethiopia Jenny's BARREL COFFEE - maturing in w...   The naughty dog
# 1                                      Rwanda KIRAMBO   The naughty dog
# 2                   Ethiopia SUKE QUTO - washed 1000g   The naughty dog
# 3              Ethiopia Jenny's BARREL COFFEE - 1000g   The naughty dog
# 4                                      Ethiopia GORAA   The naughty dog
# 5                       Ethiopia MALAWO - black honey   The naughty dog
# 6                                        Kenya NGANDU   The naughty dog
# 7                                    Colombia BOLIVAR   The naughty dog
# 8                               Ethiopia GENJI CHALLA   The naughty dog
# 9                                    UNICORN BLEND #5   The naughty dog
# 10                               Brazil RANCHO GRANDE   The naughty dog
# 11                                Yemen BANI AL AREEF   The naughty dog
# 12                        Ethiopia SUKE QUTO - washed   The naughty dog
# 13                       Brazil RANCHO GRANDE - 1000g   The naughty dog
# 14                       Brazil FAZENDA SALTO - 1000g   The naughty dog
# 15              Ethiopia MALAWO - black honey - 1000g   The naughty dog
# 16                             Ethiopia GORAA - 1000g   The naughty dog
# 17                              Kenya RUNG'ETO KII AA  Candycane Coffee
# 18                             Nicaragua PARAINEMA #2  Candycane Coffee
# 19                             El Salvador SANTA RITA  Candycane Coffee
#
#               Roast Level               Region  \
# 0                    Omni        Agaro - Jimma
# 1                    Omni  Nyamasheke District
# 2   Light to Medium Light                 Guji
# 3                    Omni        Agaro - Jimma
# 4   Light to Medium Light                 Guji
# 5   Light to Medium Light                Bensa
# 6   Light to Medium Light                Nyeri
# 7   Light to Medium Light            Antioquia
# 8   Light to Medium Light       Jimma - Oromia
# 9   Light to Medium Light                  NaN
# 10  Medium to medium dark         Sul de Minas
# 11  Light to Medium Light        Jemen - Haraz
# 12  Light to Medium Light                 Guji
# 13  Medium to medium dark         Sul de Minas
# 14  Medium to medium dark         Sul de Minas
# 15  Light to Medium Light                Bensa
# 16                    NaN                  NaN
# 17  Light to Medium Light            Kirinyaga
# 18  Medium to medium dark            Matagalpa
# 19  Light to Medium Light                  NaN
#
#                                       Flavour Profile  \
# 0              Chocolate,Caramel,Forest fruit,Whiskey
# 1   Milk chocolate,Blueberries,Mulled wine,Lemon m...
# 2            Bergamot,Peach ice tea,Black tea,Flowers
# 3              Chocolate,Caramel,Forest fruit,Whiskey
# 4              Peach tea,Květinový med,Milk chocolate
# 5   Peach ice tea,Jasmine,Forest strawberries,Pass...
# 6                         Redcurrant,Maple syrup,Lime
# 7                            Caramel,Forest fruit,Rum
# 8                Bergamot,Black tea,Nectarines,Orange
# 9      Black tea,Květinový med,Apricots,Vanilla,Jelly
# 10  Dark Bitter chocolate,Hazelnuts,Demerara sugar...
# 11  Black tea,Cotton candy,Red orange,Dried strawb...
# 12           Black tea,Flowers,Bergamot,Peach ice tea
# 13  Dark Bitter chocolate,Hazelnuts,Demerara sugar...
# 14           Sugarcane,Dark Bitter chocolate,Plum jam
# 15  Jasmine,Passion fruit,Forest strawberries,Peac...
# 16                                                NaN
# 17                        Vanilla,Blackberry jam,Lime
# 18                        Chocolate,Crème brûlée,Pear
# 19                      Blueberries,Mulled wine,Plums
#
#                                            Roast Type       Process  \
# 0   Omni (recommended for both Filter & Espresso C...        Washed
# 1   Omni (recommended for both Filter & Espresso C...       Natural
# 2                                              Filter        Washed
# 3   Omni (recommended for both Filter & Espresso C...        Washed
# 4                                              Filter       Natural
# 5                                              Filter         Honey
# 6                                              Filter        Washed
# 7                                              Filter       Natural
# 8                                              Filter        Washed
# 9                                              Filter           NaN
# 10                                           Espresso       Natural
# 11                                             Filter  Experimental
# 12                                             Filter        Washed
# 13                                           Espresso       Natural
# 14                                           Espresso       Natural
# 15                                             Filter         Honey
# 16                                                NaN           NaN
# 17                                             Filter        Washed
# 18                                           Espresso       Natural
# 19                                             Filter     Anaerobic
#
#                              Variety  \
# 0               74110,74112,Heirloom
# 1                        Red Bourbon
# 2                           Heirloom
# 3               74110,74112,Heirloom
# 4               74110,74112,Heirloom
# 5                           Heirloom
# 6                          SL28,SL34
# 7                   Castillo,Caturra
# 8                           Heirloom
# 9                  Castillo,Heirloom
# 10                        Mundo Novo
# 11                             Jaadi
# 12                          Heirloom
# 13                        Mundo Novo
# 14                    Yellow Bourbon
# 15                          Heirloom
# 16                               NaN
# 17         Batian,SL28,SL34,Ruiru 11
# 18                         Parainema
# 19  Bourbon,Hibrido de San Francisco
#
#                                        Brewing Method      Coffee Origin  \
# 0   Aeropress,Chemex,Clever dripper,French Press,H...           Ethiopia
# 1   Aeropress,Chemex,Clever dripper,French Press,H...             Rwanda
# 2   Aeropress,Chemex,Clever dripper,French Press,H...           Ethiopia
# 3   Aeropress,Chemex,Clever dripper,French Press,H...           Ethiopia
# 4   Aeropress,Chemex,Clever dripper,French Press,H...           Ethiopia
# 5   Aeropress,Chemex,Clever dripper,French Press,H...           Ethiopia
# 6   Aeropress,Chemex,Clever dripper,French Press,H...              Kenya
# 7   Aeropress,Chemex,Clever dripper,French Press,H...           Colombia
# 8   Aeropress,Chemex,Clever dripper,French Press,H...           Ethiopia
# 9   Aeropress,Chemex,Clever dripper,French Press,H...  Ethiopia,Colombia
# 10                                  Espresso,Moka pot             Brazil
# 11  Aeropress,Chemex,Clever dripper,French Press,H...              Yemen
# 12  Aeropress,Chemex,Clever dripper,French Press,H...           Ethiopia
# 13                                  Moka pot,Espresso             Brazil
# 14                                  Moka pot,Espresso             Brazil
# 15  Aeropress,Chemex,Clever dripper,French Press,H...           Ethiopia
# 16                                                NaN                NaN
# 17  Aeropress,Chemex,Clever dripper,French Press,H...              Kenya
# 18                                  Moka pot,Espresso          Nicaragua
# 19  Aeropress,Chemex,Clever dripper,French Press,H...        El Salvador
#
#     Rating Recommended  Price
# 0      4.5         96%  14,99
# 1      4.4        100%  11,99
# 2      NaN         NaN  49,99
# 3      4.5         96%  54,99
# 4      NaN         NaN  11,99
# 5      5.0        100%  12,99
# 6      5.0        100%  11,99
# 7      4.7        100%  11,99
# 8      4.3         50%  11,99
# 9      NaN         NaN  13,99
# 10     NaN         NaN   9,99
# 11     4.7        100%  18,99
# 12     NaN         NaN  11,99
# 13     NaN         NaN  39,99
# 14     4.3         83%  39,99
# 15     5.0        100%  59,99
# 16     NaN         NaN  54,99
# 17     NaN         NaN  14,99
# 18     NaN         NaN  13,99
# 19     NaN         NaN  13,99

# %%
print(df.count())
# count the number of non-empty values for each column
print("\nItems without NULL value:",df.dropna().count()[0])
# count the number of rows that have no empty values
# Out:
# Item Name          322
# Roastery           322
# Roast Level        283
# Region             309
# Flavour Profile    320
# Roast Type         283
# Process            301
# Variety            241
# Brewing Method     283
# Coffee Origin      320
# Rating             111
# Recommended        111
# Price              179
# dtype: int64
# Items without NULL value: 53

# %%
selected_columns = [['Rating', 'Recommended', 'Price'], ['Roast Level', 'Brewing Method', 'Flavour Profile']]
print(df[selected_columns[0]].count()[0])
# count the number of rows that have non-empty values in selected columns 
print(df[selected_columns[1]].count()[0])
print(df[selected_columns[0] + selected_columns[1]].count()[0])
# Out:
# 111
# 283
# 111

# %%
df['Flavour Profile'] = df['Flavour Profile'].fillna('')
flavour_lists=df['Flavour Profile'].str.split(',').tolist()
flavours = list(set([flavour for flavour_list in flavour_lists for flavour in flavour_list]))
flavours
# Out:
# ['Demerara sugar',
#  'Sugarcane',
#  'Yellow plums',
#  'Cream body',
#  '',
#  'Prunes',
#  'Cookies',
#  'Kumquat',
#  'Rum pralines',
#  'Cola',
#  'Baked apples',
#  'Dried strawberries',
#  'Dried cherries',
#  'Dried cranberries',
#  'Green apple',
#  'Mojito',
#  'Candied orange',
#  'Red orange',
#  'Tomatoes',
#  'Chocolate',
#  'Orange',
#  'Flower honey',
#  'Coke',
#  'Forest strawberries',
#  'Caramels',
#  'Mulberry',
#  'Banana',
#  'Chamomile',
#  'Carambola',
#  'White peaches',
#  'Candied fruit',
#  'Herbs',
#  'Blackberry jam',
#  'Pear',
#  'Fruit candies',
#  'Lavender',
#  'Cherry tomatoes',
#  'Dried apricots',
#  'Lemon grass',
#  'Dark Bitter chocolate',
#  'Karamelové pralinky',
#  'Marzipan',
#  'Jasmine',
#  'Cherry liqueur',
#  'Orange jam',
#  'Black tea with lemon',
#  'Marshmallow',
#  'Black cherries',
#  'Strawberries',
#  'Ripe cherries',
#  'Sweet grapefruit',
#  'Fruit',
#  'Black currant',
#  'Pecans',
#  'Sweets',
#  'Tangerines',
#  'Lískooříškový krém',
#  'Jelly',
#  'Lemonade',
#  'Hluchavka',
#  'Watermelon',
#  'Red wine',
#  'Hazelnuts',
#  'White chocolate',
#  'Rambutan',
#  'Pudding',
#  'Cocoa',
#  'Fruit juice',
#  'Pomegranate',
#  'Wine',
#  'Švestkové víno',
#  'Gingerbread',
#  'Cherry compote',
#  'Caramel',
#  'Lime jam',
#  'Candied lemon',
#  'Pineapple',
#  'Chocolate brownie',
#  'Apple',
#  'Tutti Frutti',
#  'Lemon marmalade',
#  'Fruit jam',
#  'Lemons',
#  'Cuba Libre',
#  'Mango',
#  'Elderflower',
#  'Currant',
#  'Mirabelle plum',
#  'Gooseberry',
#  'Coconut',
#  'Roses',
#  'Jatoba',
#  'Caramel cookies',
#  'Walnuts',
#  'Raspberries',
#  'Pink lemonade',
#  'Almonds in sugar',
#  'Star Anise',
#  'Chewing gums',
#  'Dried figs',
#  'Bergamot',
#  'Forest fruit',
#  'Sparkling wine',
#  'Sweetness',
#  'Milk chocolate',
#  'Blackberry',
#  'White grapes',
#  'Vanilla',
#  'Lemon peel',
#  'Poached pear',
#  'Mon Cheri',
#  'Nutella',
#  'Christmas sweets',
#  'Red fruits',
#  'Ginger',
#  'Kiwi',
#  'Malt',
#  'Stone fruit',
#  'Muscovado sugar',
#  'Papaya',
#  'Salted caramel',
#  'Květinový med',
#  'Oolong',
#  'Mulled wine',
#  'Cherry jam',
#  'Orange peel',
#  'Dried dates',
#  'Rosehip tea',
#  'Chocolate bar with raisins',
#  'Sangria',
#  'Rooibos',
#  'Passionflower',
#  'Špendlík',
#  'Sponge cakes',
#  'Cinnamon',
#  'Citronáda',
#  'Red berry fruit',
#  'Cardamom',
#  'Nuts',
#  'Cocoa nibs',
#  'Plum jam',
#  'Tropical fruit',
#  'Citrus',
#  'Grapes',
#  'Cotton candy',
#  'Maple syrup',
#  'Plums',
#  'Cheesecake',
#  'Nectarines',
#  'Nougat',
#  'Apricots',
#  'Berry fruits',
#  'Liqueur Grand Marnier',
#  'Peach tea',
#  'Chocolate pralines',
#  'Griotka',
#  'Chocolate cake',
#  'Tea',
#  'Passion fruit',
#  'Dark chocolate',
#  'Lemon ice cream',
#  'Yellow melon',
#  'Whiskey',
#  'Pomelo',
#  'Nutmeg',
#  'Orange lemonade',
#  'Peach ice tea',
#  'Kakaové lupínky',
#  'Ovesné sušenky',
#  'Blood orange',
#  'Exotic fruit',
#  'Dates',
#  'Brown sugar',
#  'Redcurrant',
#  'Crème brûlée',
#  'Jahodové lízátko',
#  'Peach',
#  'Dužinové ovoce',
#  'Cherries',
#  'Ripe fruit',
#  'Black tea',
#  'Peanut butter',
#  'Blueberries',
#  'Panela',
#  'Mléčná tyčinka MilkyWay',
#  'Spices',
#  'Dried fruit',
#  'Figs',
#  'Raisins',
#  'Raspberry jam',
#  'Green tea',
#  'Cream',
#  'Honey',
#  'Wildflowers',
#  'Lime',
#  'Gummy bears',
#  'Hibiscus',
#  'Rum',
#  'Clove',
#  'Chocolate mousse',
#  'Light acidity',
#  'Roasted nuts',
#  'Rhubarb',
#  'Almond',
#  'Currant juice',
#  'Cranberry juice',
#  'Hip',
#  'Pralines',
#  'Yuzu',
#  'Berries',
#  'Cashew',
#  'Flowers',
#  'Cranberries',
#  'Red apple',
#  'Grapefruit',
#  'Limetkový cheesecake',
#  'Pomerančový dort',
#  'White peach']

# %%
df['Brewing Method'] = df['Brewing Method'].fillna('')
flavour_lists=df['Brewing Method'].str.split(',').tolist()
methods = list(set([flavour for flavour_list in flavour_lists for flavour in flavour_list]))
methods
# Out:
# ['Espresso',
#  '',
#  'French Press',
#  'Aeropress',
#  'Clever dripper',
#  'Hario V60',
#  'Chemex',
#  'Moka pot',
#  'Vacuum Pot']

# %%
# Out:
# 'Aeropress,Chemex,Clever dripper,French Press,Hario V60,Moka pot,Vacuum Pot,Espresso'
